# %% [markdown]
# # España vs Francia, Player-Based WCPI
# Reproducción del análisis oficial PMCW.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

# %%
from src.esp_fra.build_player_indices import official_inputs, expected_goals
teams = official_inputs()
for code, team in teams.items():
    opponent = teams['FRA' if code == 'ESP' else 'ESP']
    print(code, 'WCPI=', round(team.wcpi, 4), 'lambda=', round(expected_goals(team, opponent), 6))

# %%
from src.esp_fra.simulate_match import simulate
results = simulate()
results

# %%
from src.esp_fra.scenario_analysis import load_official_scenarios
load_official_scenarios()
