# %% [markdown]
# # 02 - Simulación España vs Austria

# %%
from pmcw import MatchConfig, MatchSimulation
config = MatchConfig('Spain', 'Austria', 1.510199562, 0.896117482)
MatchSimulation(config).run().summary()
